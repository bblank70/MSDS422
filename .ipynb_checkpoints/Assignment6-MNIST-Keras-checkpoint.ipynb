# %% [markdown]
# # Assignment 6: Neural Networks
#
#
# ### You will continue work on the Digit Recognition problem in Kaggle.com this week.   As in Assignment 5, we will assess classification performance accuracy and processing time.
# ### Python TensorFlow should be used for Assignment 6. (If you experience difficulty installing TensorFlow, Python scikit-learn may be used as an alternative for Assignment 6.)

# %% [markdown]
# ## benchmark experiment:
#
# Tested neural network structures should be explored within a benchmark experiment, a factorial design with at least two levels on each of two experimental factors (at least a 2x2 completely crossed design).
# But due to the time required to fit each neural network, we will observe only one trial for each cell in the design. You will build your models on train.csv and submit your forecasts for test.csv to Kaggle.com, providing your name and user ID for each experimental trial..
#
# An example experiment could include two values for the number of nodes per inner layer and two values for the number of inner layers. Various machine learning hyperparameter settings may be used.
#
# Students are encouraged to work in study teams on this assignment, with the understanding that each student must run the code himself/herself and write an independent report of the experimental results.

# %% [markdown]
# ## Deliverable:
#     In summary, this assignment asks you to fit a number of neural networks, comparing processing time and performance across experimental treatments.
#      Processing time will be recorded for the fitting on the train.csv.  Kaggle.com accuracy scores will be reported for all benchmarks.
#
# # Management Question
#     Suppose you are a financial institution evaluating machine learning technologies for optical character recognition. Initial testing is on the MNIST digits.
#      What can you conclude from your benchmark study? Which neural network typology and hyperparameter settings would you recommend as being the most trustworthy?

# %% [markdown]
# ## Testing

# %%
# import base packages into the namespace for this program
import os
import numpy as np
import pandas as pd
from scipy import stats
from datetime import datetime

#diplay and plotting
import seaborn as sns
from IPython.display import display
import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib import cm

import tensorflow as tf
from tensorflow import keras
import kerastuner as kt

import pydot
import graphviz
import getpass

from sklearn.pipeline import Pipeline

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler

from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import cross_val_predict
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV

# %%
#password block
try:
   pwd = getpass.getpass()
except Exception as err:
   print('Error Occured : ', err)
else:
   print('Password has been entered and is character length:', len(pwd))
# Out:
# ········
# Password has been entered and is character length: 1

# %%
sender = 'pythonbrianblank@gmail.com'
reciever= 'beblank@gmail.com'

# %%
# read data for the Boston Housing Study
Digit_input = pd.read_csv("C:/Users/bblank/Documents/Northwestern MSDS/datasets/Digits-Train.csv")
Digit_test = pd.read_csv("C:/Users/bblank/Documents/Northwestern MSDS/datasets/test.csv")
#sets random seed for entire notebook
RANDOM_SEED = 1

#kfold for CV of models
kfold = KFold(n_splits=5, random_state=RANDOM_SEED)
testkfold = KFold(n_splits=2, random_state=RANDOM_SEED)
# Out:
# C:\Users\bblank\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:297: FutureWarning: Setting a random_state has no effect since shuffle is False. This will raise an error in 0.24. You should leave random_state to its default (None), or set shuffle=True.
#   FutureWarning

# %%
Digit_input.label.value_counts().sort_values()
# Out:
# 5    3795
# 8    4063
# 4    4072
# 0    4132
# 6    4137
# 2    4177
# 9    4188
# 3    4351
# 7    4401
# 1    4684
# Name: label, dtype: int64

# %% [markdown]
# ## Build our tensorboard log function

# %%
logdir = 'C:/Users/bblank/Documents/keras_logfiles'
def get_run_logdir():
    import time
    run_id = time.strftime("run_%Y_%m_%d-%H_%M_%S")
    return os.path.join('C:/Users/bblank/Documents/keras_logfiles', run_id)

run_logdir = get_run_logdir()

tensorboard_cb = keras.callbacks.TensorBoard(run_logdir)

# %% [markdown]
# ## Split our data train and validation holdout

# %%
#splits into validation and train.
train, val =  train_test_split(Digit_input, test_size = 0.2, random_state = RANDOM_SEED)


y_train = train.label.copy()
X_train = train.drop('label', axis=1)


y_val = val.label.copy()
X_val = val.drop('label', axis=1)

# %% [markdown]
# ## Quick image EDA

# %%
## plots the first 30 digits in 3 rows of 10 images. Data is unscaled
num_row = 3
num_col = 10
# plot images
fig, axes = plt.subplots(num_row, num_col, figsize=(1.5*num_col,2*num_row))
for i in range(30):
    ax = axes[i//num_col, i%num_col]
    ax.imshow(np.array(X_train.iloc[i]).reshape(28,28), cmap='gist_yarg')
    #ax.set_title('Label: {}'.format(labels[i]))
plt.tight_layout()
plt.show()

# %% [markdown]
# ## pipeline to ensure scaling is consistent from train to validation

# %%
#Scales within pipeline to ensure same scaler.

scale = Pipeline([
        ('scaler', MinMaxScaler())
        ])
        
X_train = scale.fit_transform(X_train)
x_val = scale.fit_transform(X_val)

# %% [markdown]
# # Builds and compiles model_2L10N (2 layers; 10 nodes)

# %%
model_2L10N= keras.models.Sequential()
model_2L10N.add(keras.layers.Flatten(input_shape=[28,28]))
model_2L10N.add(keras.layers.Dense(10, activation ='relu'))
model_2L10N.add(keras.layers.Dense(10, activation ='relu'))
model_2L10N.add(keras.layers.Dense(10, activation ='softmax'))

model_2L10N.summary()
model_2L10N.compile(loss= "sparse_categorical_crossentropy", 
    optimizer = 'sgd', 
    metrics = ['accuracy'])
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_1 (Flatten)          (None, 784)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                7850
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                110
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                110
# =================================================================
# Total params: 8,070
# Trainable params: 8,070
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Fits our model 2L10N

# %%
start=datetime.now()
#includes log callback for tensorboard.
train_2L10N = model_2L10N.fit(X_train, y_train, epochs=30, validation_data = (X_val, y_val), callbacks = [tensorboard_cb])

after_fit = datetime.now()
elapsed = after_fit-start
train_2L10N_elapsed= elapsed.total_seconds()
# Out:
# Epoch 1/30
# WARNING:tensorflow:Model was constructed with shape (None, 28, 28) for input KerasTensor(type_spec=TensorSpec(shape=(None, 28, 28), dtype=tf.float32, name='flatten_1_input'), name='flatten_1_input', description="created by layer 'flatten_1_input'"), but it was called on an input with incompatible shape (32, 784).
# WARNING:tensorflow:Model was constructed with shape (None, 28, 28) for input KerasTensor(type_spec=TensorSpec(shape=(None, 28, 28), dtype=tf.float32, name='flatten_1_input'), name='flatten_1_input', description="created by layer 'flatten_1_input'"), but it was called on an input with incompatible shape (32, 784).
#  991/1050 [===========================>..] - ETA: 0s - loss: 1.8005 - accuracy: 0.3934WARNING:tensorflow:Model was constructed with shape (None, 28, 28) for input KerasTensor(type_spec=TensorSpec(shape=(None, 28, 28), dtype=tf.float32, name='flatten_1_input'), name='flatten_1_input', description="created by layer 'flatten_1_input'"), but it was called on an input with incompatible shape (None, 784).
# 1050/1050 [==============================] - 2s 2ms/step - loss: 1.7719 - accuracy: 0.4054 - val_loss: 55.5400 - val_accuracy: 0.8282
# Epoch 2/30
# 1050/1050 [==============================] - 1s 954us/step - loss: 0.5691 - accuracy: 0.8407 - val_loss: 55.3414 - val_accuracy: 0.8695
# Epoch 3/30
# 1050/1050 [==============================] - 1s 891us/step - loss: 0.4307 - accuracy: 0.8768 - val_loss: 49.8077 - val_accuracy: 0.8861
# Epoch 4/30
# 1050/1050 [==============================] - 1s 867us/step - loss: 0.3811 - accuracy: 0.8878 - val_loss: 49.5918 - val_accuracy: 0.8908
# Epoch 5/30
# 1050/1050 [==============================] - 1s 940us/step - loss: 0.3593 - accuracy: 0.8959 - val_loss: 47.8036 - val_accuracy: 0.8979
# Epoch 6/30
# 1050/1050 [==============================] - 1s 964us/step - loss: 0.3329 - accuracy: 0.9057 - val_loss: 43.8604 - val_accuracy: 0.9074
# Epoch 7/30
# 1050/1050 [==============================] - 1s 870us/step - loss: 0.3159 - accuracy: 0.9097 - val_loss: 43.6033 - val_accuracy: 0.9077
# 1050/1050 [==============================] - 1s 894us/step - loss: 0.2008 - accuracy: 0.9424 - val_loss: 39.5141 - val_accuracy: 0.9223
# Epoch 27/30
# 1050/1050 [==============================] - 1s 937us/step - loss: 0.1968 - accuracy: 0.9451 - val_loss: 41.1476 - val_accuracy: 0.9204
# Epoch 28/30
# 1050/1050 [==============================] - 1s 906us/step - loss: 0.1899 - accuracy: 0.9453 - val_loss: 39.0959 - val_accuracy: 0.9219
# Epoch 29/30
# 1050/1050 [==============================] - 1s 906us/step - loss: 0.1926 - accuracy: 0.9438 - val_loss: 40.1995 - val_accuracy: 0.9226
# Epoch 30/30
# 1050/1050 [==============================] - 1s 884us/step - loss: 0.1974 - accuracy: 0.9429 - val_loss: 41.5436 - val_accuracy: 0.9186

# %%
model_2L10N_accuracy = np.max(train_2L10N.history['accuracy']).round(3)

# %%
pd.DataFrame(train_2L10N.history).plot(figsize=(8,5))
plt.grid(True)
plt.gca().set_ylim(0,1)
plt.show()

# %% [markdown]
# # Builds and compiles model_2L20N (2 layers; 20 nodes)

# %% [markdown]
# import smtplib
# sender = str(sender)
# reciever = str(reciever)
#
# gmail_user = sender
# gmail_password = pwd
#
# sent_from = gmail_user
# to = reciever
# subject = 'Your Task has completed'
# body = 'check your task taht was running\n\n- You'
#
# email_text = """\
# From: %s
# To: %s
# Subject: %s
#
# %s
# """ % (sent_from, ", ".join(to), subject, body)
#
# try:
#     server = smtplib.SMTP_SSL('smtp.gmail.com', 465)
#     server.ehlo()
#     server.login(gmail_user, gmail_password)
#     server.sendmail(sent_from, to, email_text)
#     server.close()
#
#     print ('Email sent!')
# except:
#     print ('Something went wrong...')

# %%
model_2L20N= keras.models.Sequential()
model_2L20N.add(keras.layers.Flatten(input_shape=[28,28]))
model_2L20N.add(keras.layers.Dense(20, activation ='relu'))
model_2L20N.add(keras.layers.Dense(20, activation ='relu'))
model_2L20N.add(keras.layers.Dense(10, activation ='softmax'))

model_2L20N.summary()
model_2L20N.compile(loss= "sparse_categorical_crossentropy", 
    optimizer = 'sgd', 
    metrics = ['accuracy'])
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_2 (Flatten)          (None, 784)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 20)                15700
# _________________________________________________________________
# dense_5 (Dense)              (None, 20)                420
# _________________________________________________________________
# dense_6 (Dense)              (None, 10)                210
# =================================================================
# Total params: 16,330
# Trainable params: 16,330
# Non-trainable params: 0
# _________________________________________________________________

# %%
start=datetime.now()
#includes log callback for tensorboard
train_2L20N = model_2L20N.fit(X_train, y_train, epochs=30,  validation_data = (X_val, y_val), callbacks = [tensorboard_cb])

after_fit = datetime.now()
elapsed = after_fit-start
train_2L20N_elapsed= elapsed.total_seconds()
# Out:
# Epoch 1/30
# WARNING:tensorflow:Model was constructed with shape (None, 28, 28) for input KerasTensor(type_spec=TensorSpec(shape=(None, 28, 28), dtype=tf.float32, name='flatten_2_input'), name='flatten_2_input', description="created by layer 'flatten_2_input'"), but it was called on an input with incompatible shape (32, 784).
# WARNING:tensorflow:Model was constructed with shape (None, 28, 28) for input KerasTensor(type_spec=TensorSpec(shape=(None, 28, 28), dtype=tf.float32, name='flatten_2_input'), name='flatten_2_input', description="created by layer 'flatten_2_input'"), but it was called on an input with incompatible shape (32, 784).
#  995/1050 [===========================>..] - ETA: 0s - loss: 1.7874 - accuracy: 0.4232WARNING:tensorflow:Model was constructed with shape (None, 28, 28) for input KerasTensor(type_spec=TensorSpec(shape=(None, 28, 28), dtype=tf.float32, name
# Epoch 22/30
# 1050/1050 [==============================] - 1s 916us/step - loss: 0.1474 - accuracy: 0.9571 - val_loss: 34.0909 - val_accuracy: 0.9337
# Epoch 23/30
# 1050/1050 [==============================] - 1s 921us/step - loss: 0.1444 - accuracy: 0.9599 - val_loss: 30.4374 - val_accuracy: 0.9427
# Epoch 24/30
# 1050/1050 [==============================] - 1s 929us/step - loss: 0.1403 - accuracy: 0.9597 - val_loss: 31.7045 - val_accuracy: 0.9407
# Epoch 25/30
# 1050/1050 [==============================] - 1s 924us/step - loss: 0.1373 - accuracy: 0.9610 - val_loss: 30.3816 - val_accuracy: 0.9433
# Epoch 26/30
# 1050/1050 [==============================] - 1s 919us/step - loss: 0.1299 - accuracy: 0.9639 - val_loss: 32.5923 - val_accuracy: 0.9400
# Epoch 27/30
# 1050/1050 [==============================] - 1s 929us/step - loss: 0.1350 - accuracy: 0.9604 - val_loss: 28.4626 - val_accuracy: 0.9485
# Epoch 28/30
# 1050/1050 [==============================] - 1s 929us/step - loss: 0.1254 - accuracy: 0.9642 - val_loss: 32.1296 - val_accuracy: 0.9408
# Epoch 29/30
# 1050/1050 [==============================] - 1s 943us/step - loss: 0.1262 - accuracy: 0.9624 - val_loss: 32.4215 - val_accuracy: 0.9380
# Epoch 30/30
# 1050/1050 [==============================] - 1s 940us/step - loss: 0.1151 - accuracy: 0.9674 - val_loss: 32.2769 - val_accuracy: 0.9402

# %%
model_2L20N_accuracy = np.max(train_2L20N.history['accuracy']).round(3)

# %%
pd.DataFrame(train_2L20N.history).plot(figsize=(8,5))
plt.grid(True)
plt.gca().set_ylim(0,1)
plt.show()

# %% [markdown]
# # Builds and compiles model_5L10N (5 layers; 10 nodes)

# %%
model_5L10N= keras.models.Sequential()
model_5L10N.add(keras.layers.Flatten(input_shape=[28,28]))
model_5L10N.add(keras.layers.Dense(10, activation ='relu'))
model_5L10N.add(keras.layers.Dense(10, activation ='relu'))
model_5L10N.add(keras.layers.Dense(10, activation ='relu'))
model_5L10N.add(keras.layers.Dense(10, activation ='relu'))
model_5L10N.add(keras.layers.Dense(10, activation ='softmax'))

model_5L10N.summary()
model_5L10N.compile(loss= "sparse_categorical_crossentropy", 
    optimizer = 'sgd', 
    metrics = ['accuracy'])
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_3 (Flatten)          (None, 784)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 10)                7850
# _________________________________________________________________
# dense_8 (Dense)              (None, 10)                110
# _________________________________________________________________
# dense_9 (Dense)              (None, 10)                110
# _________________________________________________________________
# dense_10 (Dense)             (None, 10)                110
# _________________________________________________________________
# dense_11 (Dense)             (None, 10)                110
# =================================================================
# Total params: 8,290
# Trainable params: 8,290
# Non-trainable params: 0
# _________________________________________________________________

# %%
start=datetime.now()

train_5L10N = model_5L10N.fit(X_train, y_train, epochs=30, validation_data = (X_val, y_val), callbacks = [tensorboard_cb])

after_fit = datetime.now()
elapsed = after_fit-start
train_5L10N_elapsed= elapsed.total_seconds()
# Out:
# Epoch 1/30
# WARNING:tensorflow:Model was constructed with shape (None, 28, 28) for input KerasTensor(type_spec=TensorSpec(shape=(None, 28, 28), dtype=tf.float32, name='flatten_3_input'), name='flatten_3_input', description="created by layer 'flatten_3_input'"), but it was called on an input with incompatible shape (32, 784).
# WARNING:tensorflow:Model was constructed with shape (None, 28, 28) for input KerasTensor(type_spec=TensorSpec(shape=(None, 28, 28), dtype=tf.float32, name='flatten_3_input'), name='flatten_3_input', description="created by layer 'flatten_3_input'"), but it was called on an input with incompatible shape (32, 784).
# 1034/1050 [============================>.] - ETA: 0s - loss: 2.1412 - accuracy: 0.1923WARNING:tensorflow:Model was constructed with shape (None, 28, 28) for input KerasTensor(type_spec=TensorSpec(shape=(None, 28, 28), dtype=tf.float32, name
# Epoch 19/30
# 1050/1050 [==============================] - 1s 949us/step - loss: 0.2129 - accuracy: 0.9374 - val_loss: 65.3571 - val_accuracy: 0.8689
# Epoch 20/30
# 1050/1050 [==============================] - 1s 970us/step - loss: 0.2098 - accuracy: 0.9372 - val_loss: 63.1808 - val_accuracy: 0.8795
# Epoch 21/30
# 1050/1050 [==============================] - 1s 946us/step - loss: 0.2010 - accuracy: 0.9410 - val_loss: 89.4050 - val_accuracy: 0.8385
# Epoch 22/30
# 1050/1050 [==============================] - 1s 948us/step - loss: 0.2004 - accuracy: 0.9411 - val_loss: 61.3714 - val_accuracy: 0.8781
# Epoch 23/30
# 1050/1050 [==============================] - 1s 955us/step - loss: 0.1949 - accuracy: 0.9407 - val_loss: 78.3941 - val_accuracy: 0.8539
# Epoch 24/30
# 1050/1050 [==============================] - 1s 941us/step - loss: 0.1913 - accuracy: 0.9433 - val_loss: 69.0584 - val_accuracy: 0.8664
# Epoch 25/30
# 1050/1050 [==============================] - 1s 973us/step - loss: 0.1859 - accuracy: 0.9426 - val_loss: 64.2297 - val_accuracy: 0.8777
# Epoch 26/30
# 1050/1050 [==============================] - 1s 952us/step - loss: 0.1814 - accuracy: 0.9460 - val_loss: 61.9785 - val_accuracy: 0.8788
# Epoch 27/30
# 1050/1050 [==============================] - 1s 968us/step - loss: 0.1836 - accuracy: 0.9434 - val_loss: 69.2176 - val_accuracy: 0.8664
# Epoch 28/30
# 1050/1050 [==============================] - 1s 967us/step - loss: 0.1802 - accuracy: 0.9453 - val_loss: 70.9698 - val_accuracy: 0.8610
# Epoch 29/30
# 1050/1050 [==============================] - 1s 953us/step - loss: 0.1773 - accuracy: 0.9469 - val_loss: 74.9115 - val_accuracy: 0.8607
# Epoch 30/30
# 1050/1050 [==============================] - 1s 947us/step - loss: 0.1821 - accuracy: 0.9466 - val_loss: 100.2741 - val_accuracy: 0.8277

# %%
model_5L10N_accuracy = np.max(train_5L10N.history['accuracy']).round(3)

# %%
pd.DataFrame(train_5L10N.history).plot(figsize=(8,5))
plt.grid(True)
plt.gca().set_ylim(0,1)
plt.show()

# %% [markdown]
# # Builds and compiles model_5L10N (5 layers; 20 nodes)

# %%
model_5L20N= keras.models.Sequential()
model_5L20N.add(keras.layers.Flatten(input_shape=[28,28]))
model_5L20N.add(keras.layers.Dense(20, activation ='relu'))
model_5L20N.add(keras.layers.Dense(20, activation ='relu'))
model_5L20N.add(keras.layers.Dense(20, activation ='relu'))
model_5L20N.add(keras.layers.Dense(20, activation ='relu'))
model_5L20N.add(keras.layers.Dense(10, activation ='softmax'))

model_5L20N.summary()
model_5L20N.compile(loss= "sparse_categorical_crossentropy", 
    optimizer = 'sgd', 
    metrics = ['accuracy'])
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_4 (Flatten)          (None, 784)               0
# _________________________________________________________________
# dense_12 (Dense)             (None, 20)                15700
# _________________________________________________________________
# dense_13 (Dense)             (None, 20)                420
# _________________________________________________________________
# dense_14 (Dense)             (None, 20)                420
# _________________________________________________________________
# dense_15 (Dense)             (None, 20)                420
# _________________________________________________________________
# dense_16 (Dense)             (None, 10)                210
# =================================================================
# Total params: 17,170
# Trainable params: 17,170
# Non-trainable params: 0
# _________________________________________________________________

# %%
start=datetime.now()

train_5L20N = model_5L10N.fit(X_train, y_train, epochs=30, validation_data = (X_val, y_val), callbacks = [tensorboard_cb])

after_fit = datetime.now()
elapsed = after_fit-start
train_5L20N_elapsed= elapsed.total_seconds()
# Out:
# Epoch 1/30
# 1050/1050 [==============================] - 2s 2ms/step - loss: 0.
# 1050/1050 [==============================] - 1s 941us/step - loss: 0.1470 - accuracy: 0.9562 - val_loss: 81.1924 - val_accuracy: 0.8488
# Epoch 20/30
# 1050/1050 [==============================] - 1s 952us/step - loss: 0.1466 - accuracy: 0.9550 - val_loss: 141.5747 - val_accuracy: 0.7654
# Epoch 21/30
# 1050/1050 [==============================] - 1s 960us/step - loss: 0.1459 - accuracy: 0.9546 - val_loss: 106.6588 - val_accuracy: 0.8121
# Epoch 22/30
# 1050/1050 [==============================] - 1s 931us/step - loss: 0.1446 - accuracy: 0.9557 - val_loss: 101.1331 - val_accuracy: 0.8242
# Epoch 23/30
# 1050/1050 [==============================] - 1s 955us/step - loss: 0.1430 - accuracy: 0.9560 - val_loss: 89.9336 - val_accuracy: 0.8350
# Epoch 24/30
# 1050/1050 [==============================] - 1s 928us/step - loss: 0.1438 - accuracy: 0.9556 - val_loss: 95.1198 - val_accuracy: 0.8392
# Epoch 25/30
# 1050/1050 [==============================] - 1s 977us/step - loss: 0.1425 - accuracy: 0.9556 - val_loss: 99.8506 - val_accuracy: 0.8251
# Epoch 26/30
# 1050/1050 [==============================] - 1s 945us/step - loss: 0.1416 - accuracy: 0.9561 - val_loss: 99.1492 - val_accuracy: 0.8171
# Epoch 27/30
# 1050/1050 [==============================] - 1s 941us/step - loss: 0.1410 - accuracy: 0.9559 - val_loss: 102.4750 - val_accuracy: 0.8202
# Epoch 28/30
# 1050/1050 [==============================] - 1s 943us/step - loss: 0.1403 - accuracy: 0.9566 - val_loss: 82.7423 - val_accuracy: 0.8475
# Epoch 29/30
# 1050/1050 [==============================] - 1s 960us/step - loss: 0.1378 - accuracy: 0.9568 - val_loss: 107.4551 - val_accuracy: 0.8115
# Epoch 30/30
# 1050/1050 [==============================] - 1s 931us/step - loss: 0.1370 - accuracy: 0.9564 - val_loss: 101.0371 - val_accuracy: 0.8219

# %%
model_5L20N_accuracy = np.max(train_5L20N.history['accuracy']).round(3)

# %%
pd.DataFrame(train_5L20N.history).plot(figsize=(8,5))
plt.grid(True)
plt.gca().set_ylim(0,1)
plt.show()

# %%
print(model_2L10N_accuracy)
print(model_2L20N_accuracy)
print(model_5L10N_accuracy)
print(model_5L20N_accuracy)
# Out:
# 0.944
# 0.964
# 0.947
# 0.957

# %%
# %reload_ext tensorboard
# %tensorboard --logdir='C:/Users/bblank/Documents/keras_logfiles' --port=6006
# Out:
# Launching TensorBoard...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-29-7be1794e9557> in <module>
#       1 get_ipython().run_line_magic('reload_ext', 'tensorboard')
# ----> 2 get_ipython().run_line_magic('tensorboard', "--logdir='C:/Users/bblank/Documents/keras_logfiles' --port=6006")
#
# ~\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2334                 kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2335             with self.builtin_trap:
# -> 2336                 result = fn(*args, **kwargs)
#    2337             return result
#    2338
#
# ~\Anaconda3\lib\site-packages\tensorboard\notebook.py in _start_magic(line)
#     126 def _start_magic(line):
#     127     """Implementation of the `%tensorboard` line magic."""
# --> 128     return start(line)
#     129
#     130
#
# ~\Anaconda3\lib\site-packages\tensorboard\notebook.py in start(args_string)
#     160
#     161     parsed_args = shlex.split(args_string, comments=True, posix=True)
# --> 162     start_result = manager.start(parsed_args)
#     163
#     164     if isinstance(start_result, manager.StartLaunched):
#
# ~\Anaconda3\lib\site-packages\tensorboard\manager.py in start(arguments, timeout)
#     423     end_time_seconds = start_time_seconds + timeout.total_seconds()
#     424     while time.time() < end_time_seconds:
# --> 425         time.sleep(poll_interval_seconds)
#     426         subprocess_result = p.poll()
#     427         if subprocess_result is not None:
#
# KeyboardInterrupt:

# %%
# %reload_ext tensorboard

# %tensorboard --logdir logdir
# Out:
# Launching TensorBoard...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-32-7501c33ad253> in <module>
#       1 get_ipython().run_line_magic('reload_ext', 'tensorboard')
#       2
# ----> 3 get_ipython().run_line_magic('tensorboard', '--logdir logdir')
#
# ~\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2334                 kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2335             with self.builtin_trap:
# -> 2336                 result = fn(*args, **kwargs)
#    2337             return result
#    2338
#
# ~\Anaconda3\lib\site-packages\tensorboard\notebook.py in _start_magic(line)
#     126 def _start_magic(line):
#     127     """Implementation of the `%tensorboard` line magic."""
# --> 128     return start(line)
#     129
#     130
#
# ~\Anaconda3\lib\site-packages\tensorboard\notebook.py in start(args_string)
#     160
#     161     parsed_args = shlex.split(args_string, comments=True, posix=True)
# --> 162     start_result = manager.start(parsed_args)
#     163
#     164     if isinstance(start_result, manager.StartLaunched):
#
# ~\Anaconda3\lib\site-packages\tensorboard\manager.py in start(arguments, timeout)
#     423     end_time_seconds = start_time_seconds + timeout.total_seconds()
#     424     while time.time() < end_time_seconds:
# --> 425         time.sleep(poll_interval_seconds)
#     426         subprocess_result = p.poll()
#     427         if subprocess_result is not None:
#
# KeyboardInterrupt:

# %%
def build_model (n_hidden=1, n_neurons=5,  learning_rate=3e-3, input_shape=[28,28]):
    model = keras.models.Sequential()
    model.add(keras.layers.InputLayer(input_shape = input_shape))
    for layer in range(n_hidden):
        model.add(keras.layers.Dense(n_neurons, activation ='relu'))
        model.add(keras.layers.Dense(10))
        optimizer = keras.optimizers.SGD(lr=learning_rate)
        model.compile(loss='sparse_categorical_crossentropy', optimizer=optimizer)
        return model

keras_classify =keras.wrappers.scikit_learn.KerasClassifier(build_model)

# %%
param_distribs ={
    "n_hidden" : [2,5],
    "n_neurons": np.arange(5,10),

}
rnd_serch_cv = RandomizedSearchCV(keras_classify, param_distribs, n_iter=10, cv=3)

rnd_serch_cv.fit(X_train, y_train, epochs = 30, validation_data = (X_val, y_val), callbacks= [keras.callbacks.EarlyStopping(patience=6)])
# Out:
# Epoch 1/30
# C:\Users\bblank\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\keras\wrappers\scikit_learn.py", line 223, in fit
#     return super(KerasClassifier, self).fit(x, y, **kwargs)
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\keras\wrappers\scikit_learn.py", line 166, in fit
#     history = self.model.fit(x, y, **fit_args)
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py", line 1100, in fit
#     tmp_logs = self.train_function(iterator)
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py", line 828, in __call__
#     result = self._call(*args, **kwds)
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py", line 871, in _call
#     self._initialize(args, kwds, add_initializers_to=initializers)
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py", line 726, in _initialize
#     *args, **kwds))
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\eager\function.py", line 2969, in _get_concrete_function_internal_garbage_collected
#     graph_function, _ = self._maybe_define_function(args, kwargs)
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\eager\function.py", line 3361, in _maybe_define_function
#     graph_function = self._create_graph_function(args, kwargs)
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\eager\function.py", line 3206, in _create_graph_function
#     capture_by_value=self._capture_by_value),
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\framework\func_graph.py", line 990, in func_graph_from_py_func
#     func_outputs = python_func(*func_args, **func_kwargs)
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py", line 634, in wrapped_fn
#     out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\framework\func_graph.py", line 977, in wrapper
#     raise e.ag_error_metadata.to_exception(e)
# ValueError: in user code:
#
#     C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py:805 train_function  *
#         return step_function(self, iterator)
#     C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py:795 step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\distribute\distribute_lib.py:1259 run
#         return self._extended.call_for_each_replica(fn, args=args, kwargs=kwargs)
#     C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\distribute\distribute_lib.py:2730 call_for_each_replica
#         return self._call_for_each_replica(fn, args, kwargs)
#     C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\distribute\distribute_lib.py:3417 _call_for_each_replica
#         return fn(*args, **kwargs)
#     C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py:788 run_step  **
#         outputs = model.train_step(data)
#     C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py:754 train_step
#         y_pred = self(x, training=True)
#     C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\base_layer.py:998 __call__
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\input_spec.py:259 assert_input_compatibility
#         ' but received input with shape ' + display_shape(x.shape))
#
#     ValueError: Input 0 of layer sequential_5 is incompatible with the layer: expected axis -1 of input shape to have value 28 but received input with shape (32, 784)
#
#
#   FitFailedWarning)
# Epoch 1/30
# Epoch 1/30
# C:\Users\bblank\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\keras\wrappers\scikit_learn.py", line 223, in fit
#     return super(KerasClassifier, self).fit(x, y, **kwargs)
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\keras\wrappers\scikit_learn.py", line 166, in fit
#     history = self.model.fit(x, y, **fit_args)
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py", line 1100, in fit
#     tmp_logs = self.train_function(iterator)
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py", line 828, in __call__
#     result = self._call(*args, **kwds)
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py", line 871, in _call
#     self._initialize(args, kwds, add_initializers_to=initializers)
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py", line 726, in _initialize
#     *args, **kwds))
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\eager\function.py", line 2969, in _get_concrete_function_internal_garbage_collected
#     graph_function, _ = self._maybe_define_function(args, kwargs)
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\eager\function.py", line 3361, in _maybe_define_function
#     graph_function = self._create_graph_function(args, kwargs)
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\eager\function.py", line 3206, in _create_graph_function
#     capture_by_value=self._capture_by_value),
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\framework\func_graph.py", line 990, in func_graph_from_py_func
#     func_outputs = python_func(*func_args, **func_kwargs)
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py", line 634, in wrapped_fn
#     out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\framework\func_graph.py", line 977, in wrapper
#     raise e.ag_error_metadata.to_exception(e)
# ValueError: in user code:
#
#     C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py:805 train_function  *
#         return step_function(self, iterator)
#     C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py:795 step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\distribute\distribute_lib.py:1259 run
#         return self._extended.call_for_each_replica(fn, args=args, kwargs=kwargs)
#     C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\distribute\distribute_lib.py:2730 call_for_each_replica
#         return self._call_for_each_replica(fn, args, kwargs)
#     C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\distribute\distribute_lib.py:3417 _call_for_each_replica
#         return fn(*args, **kwargs)
#     C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py:788 run_step  **
#         outputs = model.train_step(data)
#     C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py:754 train_step
#         y_pred = self(x, training=True)
#     C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\base_layer.py:998 __call__
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\input_spec.py:259 assert_input_compatibility
#         ' but received input with shape ' + display_shape(x.shape))
#
#     ValueError: Input 0 of layer sequential_6 is incompatible with the layer: expected axis -1 of input shape to have value 28 but received input with shape (32, 784)
#
#
#   FitFailedWarning)
# C:\Users\bblank\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\keras\wrappers\scikit_learn.py", line 223, in fit
#     return super(KerasClassifier, self).fit(x, y, **kwargs)
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\keras\wrappers\scikit_learn.py", line 166, in fit
#     history = self.model.fit(x, y, **fit_args)
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py", line 1100, in fit
#     tmp_logs = self.train_function(iterator)
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py", line 828, in __call__
#     result = self._call(*args, **kwds)
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py", line 871, in _call
#     self._initialize(args, kwds, add_initializers_to=initializers)
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py", line 726, in _initialize
#     *args, **kwds))
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\eager\function.py", line 2969, in _get_concrete_function_internal_garbage_collected
#     graph_function, _ = self._maybe_define_function(args, kwargs)
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\eager\function.py", line 3361, in _maybe_define_function
#     graph_function = self._create_graph_function(args, kwargs)
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\eager\function.py", line 3206, in _create_graph_function
#     capture_by_value=self._capture_by_value),
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\framework\func_graph.py", line 990, in func_graph_from_py_func
#     func_outputs = python_func(*func_args, **func_kwargs)
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py", line 634, in wrapped_fn
#     out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\framework\func_graph.py", line 977, in wrapper
#     raise e.ag_error_metadata.to_exception(e)
# ValueError: in user code:
#
#     C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py:805 train_function  *
#         return step_function(self, iterator)
#     C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py:795 step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\distribute\distribute_lib.py:1259 run
#         return self._extended.call_for_each_replica(fn, args=args, kwargs=kwargs)
#     C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\distribute\distribute_lib.py:2730 call_for_each_replica
#         return self._call_for_each_replica(fn, args, kwargs)
#     C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\distribute\distribute_lib.py:3417 _call_for_each_replica
#         return fn(*args, **kwargs)
#     C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py:788 run_step  **
#         outputs = model.train_step(data)
#     C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py:754 train_step
#         y_pred = self(x, training=True)
#     C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\base_layer.py:998 __call__
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\input_spec.py:259 assert_input_compatibility
#         ' but received input with shape ' + display_shape(x.shape))
#
#     ValueError: Input 0 of layer sequential_7 is incompatible with the layer: expected axis -1 of input shape to have value 28 but received input with shape (32, 784)
#
#
#   FitFailedWarning)
# Epoch 1/30
# C:\Users\bblank\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\keras\wrappers\scikit_learn.py", line 223, in fit
#     return super(KerasClassifier, self).fit(x, y, **kwargs)
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\keras\wrappers\scikit_learn.py", line 166, in fit
#     history = self.model.fit(x, y, **fit_args)
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py", line 1100, in fit
#     tmp_logs = self.train_function(iterator)
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py", line 828, in __call__
#     result = self._call(*args, **kwds)
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py", line 871, in _call
#     self._initialize(args, kwds, add_initializers_to=initializers)
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py", line 726, in _initialize
#     *args, **kwds))
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\eager\function.py", line 2969, in _get_concrete_function_internal_garbage_collected
#     graph_function, _ = self._maybe_define_function(args, kwargs)
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\eager\function.py", line 3361, in _maybe_define_function
#     graph_function = self._create_graph_function(args, kwargs)
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\eager\function.py", line 3206, in _create_graph_function
#     capture_by_value=self._capture_by_value),
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\framework\func_graph.py", line 990, in func_graph_from_py_func
#     func_outputs = python_func(*func_args, **func_kwargs)
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py", line 634, in wrapped_fn
#     out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\framework\func_graph.py", line 977, in wrapper
#     raise e.ag_error_metadata.to_exception(e)
# ValueError: in user code:
#
#     C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py:805 train_function  *
#         return step_function(self, iterator)
#     C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py:795 step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\distribute\distribute_lib.py:1259 run
#         return self._extended.call_for_each_replica(fn, args=args, kwargs=kwargs)
#     C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\distribute\distribute_lib.py:2730 call_for_each_replica
#         return self._call_for_each_replica(fn, args, kwargs)
#     C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\distribute\distribute_lib.py:3417 _call_for_each_replica
#         return fn(*args, **kwargs)
#     C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py:788 run_step  **
#         outputs = model.train_step(data)
#     C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py:754 train_step
#         y_pred = self(x, training=True)
#     C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\base_layer.py:998 __call__
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\input_spec.py:259 assert_input_compatibility
#         ' but received input with shape ' + display_shape(x.shape))
#
#     ValueError: Input 0 of layer sequential_8 is incompatible with the layer: expected axis -1 of input shape to have value 28 but received input with shape (32, 784)
#
#
#   FitFailedWarning)
# Epoch 1/30
# C:\Users\bblank\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\keras\wrappers\scikit_learn.py", line 223, in fit
#     return super(KerasClassifier, self).fit(x, y, **kwargs)
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\keras\wrappers\scikit_learn.py", line 166, in fit
#     history = self.model.fit(x, y, **fit_args)
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py", line 1100, in fit
#     tmp_logs = self.train_function(iterator)
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py", line 828, in __call__
#     result = self._call(*args, **kwds)
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py", line 871, in _call
#     self._initialize(args, kwds, add_initializers_to=initializers)
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py", line 726, in _initialize
#     *args, **kwds))
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\eager\function.py", line 2969, in _get_concrete_function_internal_garbage_collected
#     graph_function, _ = self._maybe_define_function(args, kwargs)
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\eager\function.py", line 3361, in _maybe_define_function
#     graph_function = self._create_graph_function(args, kwargs)
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\eager\function.py", line 3206, in _create_graph_function
#     capture_by_value=self._capture_by_value),
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\framework\func_graph.py", line 990, in func_graph_from_py_func
#     func_outputs = python_func(*func_args, **func_kwargs)
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py", line 634, in wrapped_fn
#     out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\framework\func_graph.py", line 977, in wrapper
#     raise e.ag_error_metadata.to_exception(e)
# ValueError: in user code:
#
#     C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py:805 train_function  *
#         return step_function(self, iterator)
#     C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py:795 step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\distribute\distribute_lib.py:1259 run
#         return self._extended.call_for_each_replica(fn, args=args, kwargs=kwargs)
#     C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\distribute\distribute_lib.py:2730 call_for_each_replica
#         return self._call_for_each_replica(fn, args, kwargs)
#     C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\distribute\distribute_lib.py:3417 _call_for_each_replica
#         return fn(*args, **kwargs)
#     C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py:788 run_step  **
#         outputs = model.train_step(data)
#     C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py:754 train_step
#         y_pred = self(x, training=True)
#     C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\base_layer.py:998 __call__
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\input_spec.py:259 assert_input_compatibility
#         ' but received input with shape ' + display_shape(x.shape))
#
#     ValueError: Input 0 of layer sequential_9 is incompatible with the layer: expected axis -1 of input shape to have value 28 but received input with shape (32, 784)
#
#
#   FitFailedWarning)
# Epoch 1/30
# C:\Users\bblank\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\keras\wrappers\scikit_learn.py", line 223, in fit
#     return super(KerasClassifier, self).fit(x, y, **kwargs)
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\keras\wrappers\scikit_learn.py", line 166, in fit
#     history = self.model.fit(x, y, **fit_args)
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py", line 1100, in fit
#     tmp_logs = self.train_function(iterator)
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py", line 828, in __call__
#     result = self._call(*args, **kwds)
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py", line 871, in _call
#     self._initialize(args, kwds, add_initializers_to=initializers)
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py", line 726, in _initialize
#     *args, **kwds))
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\eager\function.py", line 2969, in _get_concrete_function_internal_garbage_collected
#     graph_function, _ = self._maybe_define_function(args, kwargs)
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\eager\function.py", line 3361, in _maybe_define_function
#     graph_function = self._create_graph_function(args, kwargs)
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\eager\function.py", line 3206, in _create_graph_function
#     capture_by_value=self._capture_by_value),
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\framework\func_graph.py", line 990, in func_graph_from_py_func
#     func_outputs = python_func(*func_args, **func_kwargs)
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py", line 634, in wrapped_fn
#     out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\framework\func_graph.py", line 977, in wrapper
#     raise e.ag_error_metadata.to_exception(e)
# ValueError: in user code:
#
#     C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py:805 train_function  *
#         return step_function(self, iterator)
#     C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py:795 step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\distribute\distribute_lib.py:1259 run
#         return self._extended.call_for_each_replica(fn, args=args, kwargs=kwargs)
#     C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\distribute\distribute_lib.py:2730 call_for_each_replica
#         return self._call_for_each_replica(fn, args, kwargs)
#     C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\distribute\distribute_lib.py:3417 _call_for_each_replica
#         return fn(*args, **kwargs)
#     C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py:788 run_step  **
#         outputs = model.train_step(data)
#     C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py:754 train_step
#         y_pred = self(x, training=True)
#     C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\base_layer.py:998 __call__
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\input_spec.py:259 assert_input_compatibility
#         ' but received input with shape ' + display_shape(x.shape))
#
#     ValueError: Input 0 of layer sequential_10 is incompatible with the layer: expected axis -1 of input shape to have value 28 but received input with shape (32, 784)
#
#
#   FitFailedWarning)
# Epoch 1/30
# C:\Users\bblank\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\keras\wrappers\scikit_learn.py", line 223, in fit
#     return super(KerasClassifier, self).fit(x, y, **kwargs)
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\keras\wrappers\scikit_learn.py", line 166, in fit
#     history = self.model.fit(x, y, **fit_args)
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py", line 1100, in fit
#     tmp_logs = self.train_function(iterator)
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py", line 828, in __call__
#     result = self._call(*args, **kwds)
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py", line 871, in _call
#     self._initialize(args, kwds, add_initializers_to=initializers)
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py", line 726, in _initialize
#     *args, **kwds))
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\eager\function.py", line 2969, in _get_concrete_function_internal_garbage_collected
#     graph_function, _ = self._maybe_define_function(args, kwargs)
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\eager\function.py", line 3361, in _maybe_define_function
#     graph_function = self._create_graph_function(args, kwargs)
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\eager\function.py", line 3206, in _create_graph_function
#     capture_by_value=self._capture_by_value),
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\framework\func_graph.py", line 990, in func_graph_from_py_func
#     func_outputs = python_func(*func_args, **func_kwargs)
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py", line 634, in wrapped_fn
#     out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\framework\func_graph.py", line 977, in wrapper
#     raise e.ag_error_metadata.to_exception(e)
# ValueError: in user code:
#
#     C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py:805 train_function  *
#         return step_function(self, iterator)
#     C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py:795 step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\distribute\distribute_lib.py:1259 run
#         return self._extended.call_for_each_replica(fn, args=args, kwargs=kwargs)
#     C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\distribute\distribute_lib.py:2730 call_for_each_replica
#         return self._call_for_each_replica(fn, args, kwargs)
#     C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\distribute\distribute_lib.py:3417 _call_for_each_replica
#         return fn(*args, **kwargs)
#     C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py:788 run_step  **
#         outputs = model.train_step(data)
#     C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py:754 train_step
#         y_pred = self(x, training=True)
#     C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\base_layer.py:998 __call__
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\input_spec.py:259 assert_input_compatibility
#         ' but received input with shape ' + display_shape(x.shape))
#
#     ValueError: Input 0 of layer sequential_11 is incompatible with the layer: expected axis -1 of input shape to have value 28 but received input with shape (32, 784)
#
#
#   FitFailedWarning)
# Epoch 1/30
# Epoch 1/30
# C:\Users\bblank\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\keras\wrappers\scikit_learn.py", line 223, in fit
#     return super(KerasClassifier, self).fit(x, y, **kwargs)
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\keras\wrappers\scikit_learn.py", line 166, in fit
#     history = self.model.fit(x, y, **fit_args)
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py", line 1100, in fit
#     tmp_logs = self.train_function(iterator)
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py", line 828, in __call__
#     result = self._call(*args, **kwds)
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py", line 871, in _call
#     self._initialize(args, kwds, add_initializers_to=initializers)
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py", line 726, in _initialize
#     *args, **kwds))
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\eager\function.py", line 2969, in _get_concrete_function_internal_garbage_collected
#     graph_function, _ = self._maybe_define_function(args, kwargs)
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\eager\function.py", line 3361, in _maybe_define_function
#     graph_function = self._create_graph_function(args, kwargs)
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\eager\function.py", line 3206, in _create_graph_function
#     capture_by_value=self._capture_by_value),
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\framework\func_graph.py", line 990, in func_graph_from_py_func
#     func_outputs = python_func(*func_args, **func_kwargs)
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py", line 634, in wrapped_fn
#     out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\framework\func_graph.py", line 977, in wrapper
#     raise e.ag_error_metadata.to_exception(e)
# ValueError: in user code:
#
#     C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py:805 train_function  *
#         return step_function(self, iterator)
#     C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py:795 step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\distribute\distribute_lib.py:1259 run
#         return self._extended.call_for_each_replica(fn, args=args, kwargs=kwargs)
#     C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\distribute\distribute_lib.py:2730 call_for_each_replica
#         return self._call_for_each_replica(fn, args, kwargs)
#     C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\distribute\distribute_lib.py:3417 _call_for_each_replica
#         return fn(*args, **kwargs)
#     C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py:788 run_step  **
#         outputs = model.train_step(data)
#     C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py:754 train_step
#         y_pred = self(x, training=True)
#     C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\base_layer.py:998 __call__
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\input_spec.py:259 assert_input_compatibility
#         ' but received input with shape ' + display_shape(x.shape))
#
#     ValueError: Input 0 of layer sequential_12 is incompatible with the layer: expected axis -1 of input shape to have value 28 but received input with shape (32, 784)
#
#
#   FitFailedWarning)
# C:\Users\bblank\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\keras\wrappers\scikit_learn.py", line 223, in fit
#     return super(KerasClassifier, self).fit(x, y, **kwargs)
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\keras\wrappers\scikit_learn.py", line 166, in fit
#     history = self.model.fit(x, y, **fit_args)
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py", line 1100, in fit
#     tmp_logs = self.train_function(iterator)
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py", line 828, in __call__
#     result = self._call(*args, **kwds)
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py", line 871, in _call
#     self._initialize(args, kwds, add_initializers_to=initializers)
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py", line 726, in _initialize
#     *args, **kwds))
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\eager\function.py", line 2969, in _get_concrete_function_internal_garbage_collected
#     graph_function, _ = self._maybe_define_function(args, kwargs)
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\eager\function.py", line 3361, in _maybe_define_function
#     graph_function = self._create_graph_function(args, kwargs)
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\eager\function.py", line 3206, in _create_graph_function
#     capture_by_value=self._capture_by_value),
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\framework\func_graph.py", line 990, in func_graph_from_py_func
#     func_outputs = python_func(*func_args, **func_kwargs)
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py", line 634, in wrapped_fn
#     out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\framework\func_graph.py", line 977, in wrapper
#     raise e.ag_error_metadata.to_exception(e)
# ValueError: in user code:
#
#     C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py:805 train_function  *
#         return step_function(self, iterator)
#     C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py:795 step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\distribute\distribute_lib.py:1259 run
#         return self._extended.call_for_each_replica(fn, args=args, kwargs=kwargs)
#     C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\distribute\distribute_lib.py:2730 call_for_each_replica
#         return self._call_for_each_replica(fn, args, kwargs)
#     C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\distribute\distribute_lib.py:3417 _call_for_each_replica
#         return fn(*args, **kwargs)
#     C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py:788 run_step  **
#         outputs = model.train_step(data)
#     C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py:754 train_step
#         y_pred = self(x, training=True)
#     C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\base_layer.py:998 __call__
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\input_spec.py:259 assert_input_compatibility
#         ' but received input with shape ' + display_shape(x.shape))
#
#     ValueError: Input 0 of layer sequential_13 is incompatible with the layer: expected axis -1 of input shape to have value 28 but received input with shape (32, 784)
#
#
#   FitFailedWarning)
# C:\Users\bblank\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\keras\wrappers\scikit_learn.py", line 223, in fit
#     return super(KerasClassifier, self).fit(x, y, **kwargs)
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\keras\wrappers\scikit_learn.py", line 166, in fit
#     history = self.model.fit(x, y, **fit_args)
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py", line 1100, in fit
#     tmp_logs = self.train_function(iterator)
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py", line 828, in __call__
#     result = self._call(*args, **kwds)
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py", line 871, in _call
#     self._initialize(args, kwds, add_initializers_to=initializers)
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py", line 726, in _initialize
#     *args, **kwds))
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\eager\function.py", line 2969, in _get_concrete_function_internal_garbage_collected
#     graph_function, _ = self._maybe_define_function(args, kwargs)
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\eager\function.py", line 3361, in _maybe_define_function
#     graph_function = self._create_graph_function(args, kwargs)
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\eager\function.py", line 3206, in _create_graph_function
#     capture_by_value=self._capture_by_value),
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\framework\func_graph.py", line 990, in func_graph_from_py_func
#     func_outputs = python_func(*func_args, **func_kwargs)
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py", line 634, in wrapped_fn
#     out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\framework\func_graph.py", line 977, in wrapper
#     raise e.ag_error_metadata.to_exception(e)
# ValueError: in user code:
#
#     C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py:805 train_function  *
#         return step_function(self, iterator)
#     C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py:795 step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\distribute\distribute_lib.py:1259 run
#         return self._extended.call_for_each_replica(fn, args=args, kwargs=kwargs)
#     C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\distribute\distribute_lib.py:2730 call_for_each_replica
#         return self._call_for_each_replica(fn, args, kwargs)
#     C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\distribute\distribute_lib.py:3417 _call_for_each_replica
#         return fn(*args, **kwargs)
#     C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py:788 run_step  **
#         outputs = model.train_step(data)
#     C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py:754 train_step
#         y_pred = self(x, training=True)
#     C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\base_layer.py:998 __call__
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\input_spec.py:259 assert_input_compatibility
#         ' but received input with shape ' + display_shape(x.shape))
#
#     ValueError: Input 0 of layer sequential_14 is incompatible with the layer: expected axis -1 of input shape to have value 28 but received input with shape (32, 784)
#
#
#   FitFailedWarning)
# Epoch 1/30
# Epoch 1/30
# C:\Users\bblank\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\keras\wrappers\scikit_learn.py", line 223, in fit
#     return super(KerasClassifier, self).fit(x, y, **kwargs)
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\keras\wrappers\scikit_learn.py", line 166, in fit
#     history = self.model.fit(x, y, **fit_args)
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py", line 1100, in fit
#     tmp_logs = self.train_function(iterator)
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py", line 828, in __call__
#     result = self._call(*args, **kwds)
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py", line 871, in _call
#     self._initialize(args, kwds, add_initializers_to=initializers)
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py", line 726, in _initialize
#     *args, **kwds))
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\eager\function.py", line 2969, in _get_concrete_function_internal_garbage_collected
#     graph_function, _ = self._maybe_define_function(args, kwargs)
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\eager\function.py", line 3361, in _maybe_define_function
#     graph_function = self._create_graph_function(args, kwargs)
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\eager\function.py", line 3206, in _create_graph_function
#     capture_by_value=self._capture_by_value),
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\framework\func_graph.py", line 990, in func_graph_from_py_func
#     func_outputs = python_func(*func_args, **func_kwargs)
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py", line 634, in wrapped_fn
#     out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\framework\func_graph.py", line 977, in wrapper
#     raise e.ag_error_metadata.to_exception(e)
# ValueError: in user code:
#
#     C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py:805 train_function  *
#         return step_function(self, iterator)
#     C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py:795 step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\distribute\distribute_lib.py:1259 run
#         return self._extended.call_for_each_replica(fn, args=args, kwargs=kwargs)
#     C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\distribute\distribute_lib.py:2730 call_for_each_replica
#         return self._call_for_each_replica(fn, args, kwargs)
#     C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\distribute\distribute_lib.py:3417 _call_for_each_replica
#         return fn(*args, **kwargs)
#     C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py:788 run_step  **
#         outputs = model.train_step(data)
#     C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py:754 train_step
#         y_pred = self(x, training=True)
#     C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\base_layer.py:998 __call__
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\input_spec.py:259 assert_input_compatibility
#         ' but received input with shape ' + display_shape(x.shape))
#
#     ValueError: Input 0 of layer sequential_15 is incompatible with the layer: expected axis -1 of input shape to have value 28 but received input with shape (32, 784)
#
#
#   FitFailedWarning)
# Epoch 1/30
# C:\Users\bblank\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\keras\wrappers\scikit_learn.py", line 223, in fit
#     return super(KerasClassifier, self).fit(x, y, **kwargs)
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\keras\wrappers\scikit_learn.py", line 166, in fit
#     history = self.model.fit(x, y, **fit_args)
# ...
#         return self._call_for_each_replica(fn, args, kwargs)
#     C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\distribute\distribute_lib.py:3417 _call_for_each_replica
#         return fn(*args, **kwargs)
#     C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py:788 run_step  **
#         outputs = model.train_step(data)
#     C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py:754 train_step
#         y_pred = self(x, training=True)
#     C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\base_layer.py:998 __call__
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\input_spec.py:259 assert_input_compatibility
#         ' but received input with shape ' + display_shape(x.shape))
#
#     ValueError: Input 0 of layer sequential_31 is incompatible with the layer: expected axis -1 of input shape to have value 28 but received input with shape (32, 784)
#
#
#   FitFailedWarning)
# C:\Users\bblank\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\keras\wrappers\scikit_learn.py", line 223, in fit
#     return super(KerasClassifier, self).fit(x, y, **kwargs)
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\keras\wrappers\scikit_learn.py", line 166, in fit
#     history = self.model.fit(x, y, **fit_args)
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py", line 1100, in fit
#     tmp_logs = self.train_function(iterator)
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py", line 828, in __call__
#     result = self._call(*args, **kwds)
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py", line 871, in _call
#     self._initialize(args, kwds, add_initializers_to=initializers)
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py", line 726, in _initialize
#     *args, **kwds))
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\eager\function.py", line 2969, in _get_concrete_function_internal_garbage_collected
#     graph_function, _ = self._maybe_define_function(args, kwargs)
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\eager\function.py", line 3361, in _maybe_define_function
#     graph_function = self._create_graph_function(args, kwargs)
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\eager\function.py", line 3206, in _create_graph_function
#     capture_by_value=self._capture_by_value),
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\framework\func_graph.py", line 990, in func_graph_from_py_func
#     func_outputs = python_func(*func_args, **func_kwargs)
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py", line 634, in wrapped_fn
#     out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\framework\func_graph.py", line 977, in wrapper
#     raise e.ag_error_metadata.to_exception(e)
# ValueError: in user code:
#
#     C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py:805 train_function  *
#         return step_function(self, iterator)
#     C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py:795 step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\distribute\distribute_lib.py:1259 run
#         return self._extended.call_for_each_replica(fn, args=args, kwargs=kwargs)
#     C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\distribute\distribute_lib.py:2730 call_for_each_replica
#         return self._call_for_each_replica(fn, args, kwargs)
#     C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\distribute\distribute_lib.py:3417 _call_for_each_replica
#         return fn(*args, **kwargs)
#     C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py:788 run_step  **
#         outputs = model.train_step(data)
#     C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py:754 train_step
#         y_pred = self(x, training=True)
#     C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\base_layer.py:998 __call__
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\input_spec.py:259 assert_input_compatibility
#         ' but received input with shape ' + display_shape(x.shape))
#
#     ValueError: Input 0 of layer sequential_32 is incompatible with the layer: expected axis -1 of input shape to have value 28 but received input with shape (32, 784)
#
#
#   FitFailedWarning)
# Epoch 1/30
# Epoch 1/30
# C:\Users\bblank\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\keras\wrappers\scikit_learn.py", line 223, in fit
#     return super(KerasClassifier, self).fit(x, y, **kwargs)
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\keras\wrappers\scikit_learn.py", line 166, in fit
#     history = self.model.fit(x, y, **fit_args)
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py", line 1100, in fit
#     tmp_logs = self.train_function(iterator)
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py", line 828, in __call__
#     result = self._call(*args, **kwds)
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py", line 871, in _call
#     self._initialize(args, kwds, add_initializers_to=initializers)
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py", line 726, in _initialize
#     *args, **kwds))
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\eager\function.py", line 2969, in _get_concrete_function_internal_garbage_collected
#     graph_function, _ = self._maybe_define_function(args, kwargs)
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\eager\function.py", line 3361, in _maybe_define_function
#     graph_function = self._create_graph_function(args, kwargs)
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\eager\function.py", line 3206, in _create_graph_function
#     capture_by_value=self._capture_by_value),
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\framework\func_graph.py", line 990, in func_graph_from_py_func
#     func_outputs = python_func(*func_args, **func_kwargs)
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py", line 634, in wrapped_fn
#     out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\framework\func_graph.py", line 977, in wrapper
#     raise e.ag_error_metadata.to_exception(e)
# ValueError: in user code:
#
#     C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py:805 train_function  *
#         return step_function(self, iterator)
#     C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py:795 step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\distribute\distribute_lib.py:1259 run
#         return self._extended.call_for_each_replica(fn, args=args, kwargs=kwargs)
#     C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\distribute\distribute_lib.py:2730 call_for_each_replica
#         return self._call_for_each_replica(fn, args, kwargs)
#     C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\distribute\distribute_lib.py:3417 _call_for_each_replica
#         return fn(*args, **kwargs)
#     C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py:788 run_step  **
#         outputs = model.train_step(data)
#     C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py:754 train_step
#         y_pred = self(x, training=True)
#     C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\base_layer.py:998 __call__
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\input_spec.py:259 assert_input_compatibility
#         ' but received input with shape ' + display_shape(x.shape))
#
#     ValueError: Input 0 of layer sequential_33 is incompatible with the layer: expected axis -1 of input shape to have value 28 but received input with shape (32, 784)
#
#
#   FitFailedWarning)
# Epoch 1/30
# C:\Users\bblank\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\keras\wrappers\scikit_learn.py", line 223, in fit
#     return super(KerasClassifier, self).fit(x, y, **kwargs)
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\keras\wrappers\scikit_learn.py", line 166, in fit
#     history = self.model.fit(x, y, **fit_args)
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py", line 1100, in fit
#     tmp_logs = self.train_function(iterator)
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py", line 828, in __call__
#     result = self._call(*args, **kwds)
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py", line 871, in _call
#     self._initialize(args, kwds, add_initializers_to=initializers)
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py", line 726, in _initialize
#     *args, **kwds))
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\eager\function.py", line 2969, in _get_concrete_function_internal_garbage_collected
#     graph_function, _ = self._maybe_define_function(args, kwargs)
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\eager\function.py", line 3361, in _maybe_define_function
#     graph_function = self._create_graph_function(args, kwargs)
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\eager\function.py", line 3206, in _create_graph_function
#     capture_by_value=self._capture_by_value),
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\framework\func_graph.py", line 990, in func_graph_from_py_func
#     func_outputs = python_func(*func_args, **func_kwargs)
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py", line 634, in wrapped_fn
#     out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#   File "C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\framework\func_graph.py", line 977, in wrapper
#     raise e.ag_error_metadata.to_exception(e)
# ValueError: in user code:
#
#     C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py:805 train_function  *
#         return step_function(self, iterator)
#     C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py:795 step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\distribute\distribute_lib.py:1259 run
#         return self._extended.call_for_each_replica(fn, args=args, kwargs=kwargs)
#     C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\distribute\distribute_lib.py:2730 call_for_each_replica
#         return self._call_for_each_replica(fn, args, kwargs)
#     C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\distribute\distribute_lib.py:3417 _call_for_each_replica
#         return fn(*args, **kwargs)
#     C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py:788 run_step  **
#         outputs = model.train_step(data)
#     C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py:754 train_step
#         y_pred = self(x, training=True)
#     C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\base_layer.py:998 __call__
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     C:\Users\bblank\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\input_spec.py:259 assert_input_compatibility
#         ' but received input with shape ' + display_shape(x.shape))
#
#     ValueError: Input 0 of layer sequential_34 is incompatible with the layer: expected axis -1 of input shape to have value 28 but received input with shape (32, 784)
#
#
#   FitFailedWarning)
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-34-83d3aea7031a> in <module>
#       6 rnd_serch_cv = RandomizedSearchCV(keras_classify, param_distribs, n_iter=10, cv=3)
#       7
# ----> 8 rnd_serch_cv.fit(X_train, y_train, epochs = 30, validation_data = (X_val, y_val), callbacks= [keras.callbacks.EarlyStopping(patience=6)])
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# ~\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py in fit(self, X, y, groups, **fit_params)
#     760             # of the params are estimators as well.
#     761             self.best_estimator_ = clone(clone(base_estimator).set_params(
# --> 762                 **self.best_params_))
#     763             refit_start_time = time.time()
#     764             if y is not None:
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# ~\Anaconda3\lib\site-packages\sklearn\base.py in clone(estimator, safe)
#      96             raise RuntimeError('Cannot clone object %s, as the constructor '
#      97                                'either does not set or modifies parameter %s' %
# ---> 98                                (estimator, name))
#      99     return new_object
#     100
#
# RuntimeError: Cannot clone object <tensorflow.python.keras.wrappers.scikit_learn.KerasClassifier object at 0x00000258A9F74EC8>, as the constructor either does not set or modifies parameter n_neurons

# %% [markdown]
# keras_classify.fit(X_train, y_train, epochs = 30, validation_data = (X_val, y_val), callbacks= [keras.callbacks.EarlyStopping(patience=6)])
#
# keras_score = keras_classify.score(X_test, y_test)

# %%
def model_builder(hp):
  model = keras.Sequential()
  model.add(keras.layers.Flatten(input_shape=(28, 28)))

  # Tune the number of units in the first Dense layer
  # Choose an optimal value between 32-512
  hp_units = hp.Int('units', min_value=10, max_value=20, step=5)
  model.add(keras.layers.Dense(units=hp_units, activation='relu'))
  model.add(keras.layers.Dense(10))

  # Tune the learning rate for the optimizer
  # Choose an optimal value from 0.01, 0.001, or 0.0001
  hp_learning_rate = hp.Choice('learning_rate', values=[1e-3, 3e-3, 5e-3])

  model.compile(optimizer=keras.optimizers.Adam(learning_rate=hp_learning_rate),
                loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
                metrics=['accuracy'])

  return model

# %%
tuner = kt.Hyperband(model_builder,
                     objective='val_accuracy',
                     max_epochs=10,
                     factor=3,
                     directory=logdir,
                     project_name='intro_to_kt')
                     
stop_early = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5)

# %%
tuner.search(X_train, y_train, epochs=30, validation_split=0.2, callbacks=[stop_early])

# Get the optimal hyperparameters
best_hps=tuner.get_best_hyperparameters(num_trials=1)[0]

print(f"""
The hyperparameter search is complete. The optimal number of units in the first densely-connected
layer is {best_hps.get('units')} and the optimal learning rate for the optimizer
is {best_hps.get('learning_rate')}.
""")

# %%
best_hps.get('learning_rate')
best_hps.get('units')
